# %%
#dependencies
import pandas as pd
import numpy as np  
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn.preprocessing import StandardScaler

# %%
#import data
data = pd.read_csv('top_10_percent_answers.csv')
data.head()
# Out:
#   occupation  family_history  treatment        days_indoors  growing_stress  \
# 0  Housewife              -1         -1           1-14 days               0
# 1  Housewife               1          1           1-14 days               0
# 2    Student              -1         -1  More than 2 months               0
# 3  Corporate              -1         -1          31-60 days               0
# 4  Corporate              -1         -1          31-60 days               1
#
#    mental_health_history  mood_swings  coping_struggles  work_interest  \
# 0                      0           -1                -1             -1
# 1                      0           -1                -1             -1
# 2                     -1            0                 1              1
# 3                     -1            0                -1             -1
# 4                      0            1                -1             -1
#
#    social_weakness  percentage
# 0               -1    0.181779
# ...

# %%
#pvalue between family_history and treatment

# %%
#frequency distribution of the target variable
sns.scatterplot(data=data, x="work_interest", y="mental_health_history", hue="days_indoors")
# Out:
# <Axes: xlabel='work_interest', ylabel='mental_health_history'>
